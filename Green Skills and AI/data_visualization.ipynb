# %%
import numpy as np
import matplotlib.pyplot as plt
y1=[2, 3, 4.5]
y2=[1, 1.5, 5]
plt.plot(y1)
plt.plot(y2)
plt.legend(["blue", "green"], loc="lower right")
plt.show()

# %%
#pair plot: visualizing relaitonships between 2 values for consumption
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Solar": [1200, 1500, 1300],
    "Wind": [3400, 3600, 3200],
    "Hydropower": [2900, 3100, 2800],
    "Biomass": [2500, 2700, 2400]
}
df=pd.DataFrame(data)
#create a pair plot
sns.pairplot(df)
plt.show()

# %%
#Heatmap: shows correlation between different types of energy consumption
#create a heatmap to show correlation matrix
correlation_matrix = df.corr()
#plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#add title
plt.title('Corrrelation between energy sources')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2e1cf5d99ec2> in <cell line: 3>()
#       1 #Heatmap: shows correlation between different types of energy consumption
#       2 #create a heatmap to show correlation matrix
# ----> 3 correlation_matrix = df.corr()
#       4 #plot heatmap
#       5 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
# ...

# %%
#box plot: comparing the distributuion of energy consumption by different sources

#create a box plot
sns.boxplot(data=df)
#add title
plt.title('Distribution of energy consumption by source')
plt.show()

# %%
#create a violin plot
sns.violinplot(data=df)
plt.title('violin plot of energy consumption distributions')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
energy_values = [100, 200, 300, 400, 500]
carbon_emissions = [10, 20, 25, 40, 50]
df_reg = pd.DataFrame({
    'Energy Consumption': energy_values,
    'Carbon Emissions': carbon_emissions
})
sns.regplot(x='Energy Consumption', y='Carbon Emissions', data=df_reg)
#add title

plt.show()

# %%
#3D plot: lines and points

from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')
z = np.linspace(0,1,1000)
x=z*np.sin(25*z)
y=z*np.cos(25*z)
ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('/content/IRIS.csv')

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#pair plot
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#create a pair plot
sns.pairplot(df)
plt.show()

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.pairplot(df,hue = 'species', palette="husl",size=2)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#heatmap
df = pd.read_csv("IRIS.csv")


df['species'] = df['species'].astype('category').cat.codes

corr = df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
#box plot
#create a box plot
sns.boxplot(data=df)
#add title
plt.title('IRIS flower data')
plt.show()

# %%
#violin plot
sns.violinplot(data=df)
plt.title('violin plot')
plt.show()

# %%
#graphs with different colors using 'hue' and tip size using 'size'
plt.figure(figsize=(10,7))
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=df)
plt.show()
